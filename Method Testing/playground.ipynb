# %%
import DataPrep

moduleTopics = DataPrep.getModuleTopics()

# %%
moduleTopics
# Out:
#         INDEX                                               NAME  \
# 0       65067                       Entwerfen und Konstruieren 2
# 1       65067                       Entwerfen und Konstruieren 2
# 2       65067                       Entwerfen und Konstruieren 2
# 3       65067                       Entwerfen und Konstruieren 2
# 4       65067                       Entwerfen und Konstruieren 2
# ...       ...                                                ...
# 530330  50334  Künstlerische Musikpraxis 1: Zentrale künstler...
# 530331  48598                                      Museumspraxis
# 530332  49835                          Interkulturelle Kompetenz
# 530333  48549                  Aufbaumodul Pädagogik (Nebenfach)
# 530334  61361         Management Modules from other Universities
#
#                                                      SPAN  TOPIC_ID  \
# 0                                                   plans    378010
# ...
