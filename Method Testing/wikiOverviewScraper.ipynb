# %%
from bs4 import BeautifulSoup

# Load the HTML file
file_path = "database/wikipedia_overview_page.html"

# Load the HTML file
with open(file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# %%
content_container = soup.find('div', class_='mw-content-container')

# %%
links = content_container.find_all('a')

# %%
links
# Out:
# [<a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/%D9%88%D9%8A%D9%83%D9%8A%D8%A8%D9%8A%D8%AF%D9%8A%D8%A7:%D8%AA%D8%B5%D9%81%D8%AD" hreflang="ar" lang="ar" title="ويكيبيديا:تصفح – Arabic"><span>العربية</span></a>,
#  <a class="interlanguage-link-target" href="https://as.wikipedia.org/wiki/%E0%A7%B1%E0%A6%BF%E0%A6%95%E0%A6%BF%E0%A6%9A%27%E0%A7%B0%E0%A6%BE:%E0%A6%AA%E0%A6%9E%E0%A7%8D%E0%A6%9C%E0%A7%80/%E0%A6%B8%E0%A6%BE%E0%A7%B0%E0%A6%BE%E0%A6%82%E0%A6%B6" hreflang="as" lang="as" title="ৱিকিচ'ৰা:পঞ্জী/সাৰাংশ – Assamese"><span>অসমীয়া</span></a>,
# ...

# %%
import wikipediaapi

wiki = wikipediaapi.Wikipedia(user_agent="User-Agent: CoolBot/0.0 (https://example.org/coolbot/; coolbot@example.org) generic-library/0.0")
page = wiki.page("matrix multiplication")
categories = page.categories

# %%
categories
# Out:
# {'Category:All articles containing potentially dated statements': Category:All articles containing potentially dated statements (id: ??, ns: 14),
#  'Category:Articles containing potentially dated statements from January 2024': Category:Articles containing potentially dated statements from January 2024 (id: ??, ns: 14),
#  'Category:Articles with short description': Category:Articles with short description (id: ??, ns: 14),
#  'Category:Bilinear maps': Category:Bilinear maps (id: ??, ns: 14),
#  'Category:CS1 German-language sources (de)': Category:CS1 German-language sources (de) (id: ??, ns: 14),
#  'Category:Commons category link is on Wikidata': Category:Commons category link is on Wikidata (id: ??, ns: 14),
#  'Category:Matrix theory': Category:Matrix theory (id: ??, ns: 14),
#  'Category:Multiplication': Category:Multiplication (id: ??, ns: 14),
#  'Category:Numerical linear algebra': Category:Numerical linear algebra (id: ??, ns: 14),
# ...
